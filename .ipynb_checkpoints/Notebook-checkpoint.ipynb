# %% [markdown]
# ## LOADING DATA

# %%
# ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
from dateutil.parser import parse

# %%
# loading datasets
pd.set_option('max_column', None)
train = pd.read_csv('data/train.csv', parse_dates=['Date'])
test = pd.read_csv('data/test.csv', parse_dates=['Date'])
store = pd.read_csv('data/store.csv')

# %%
# checking train dataset
train
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            2          5 2015-07-31   6064        625     1      1
# 2            3          5 2015-07-31   8314        821     1      1
# 3            4          5 2015-07-31  13995       1498     1      1
# 4            5          5 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017204   1111          2 2013-01-01      0          0     0      0
# 1017205   1112          2 2013-01-01      0          0     0      0
# 1017206   1113          2 2013-01-01      0          0     0      0
# 1017207   1114          2 2013-01-01      0          0     0      0
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# 2                  0              1
# ...

# %%
# checking test dataset
test
# Out:
#           Id  Store  DayOfWeek       Date  Open  Promo StateHoliday  \
# 0          1      1          4 2015-09-17   1.0      1            0
# 1          2      3          4 2015-09-17   1.0      1            0
# 2          3      7          4 2015-09-17   1.0      1            0
# 3          4      8          4 2015-09-17   1.0      1            0
# 4          5      9          4 2015-09-17   1.0      1            0
# ...      ...    ...        ...        ...   ...    ...          ...
# 41083  41084   1111          6 2015-08-01   1.0      0            0
# 41084  41085   1112          6 2015-08-01   1.0      0            0
# 41085  41086   1113          6 2015-08-01   1.0      0            0
# 41086  41087   1114          6 2015-08-01   1.0      0            0
# 41087  41088   1115          6 2015-08-01   1.0      0            0
#
#        SchoolHoliday
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...

# %%
# checking store dataset
store
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 1         2         a          a                570.0
# 2         3         a          a              14130.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# ...     ...       ...        ...                  ...
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 1                          11.0                    2007.0       1
# 2                          12.0                    2006.0       1
# ...

# %% [markdown]
# The store dataset contains extra information about each store in the train and test sets. Therefore the store dataframe will be merged with the train and test dataframes.

# %%
# merging train and store
df_train = pd.merge(train, store, on='Store')
df_train
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            1          4 2015-07-30   5020        546     1      1
# 2            1          3 2015-07-29   4782        523     1      1
# 3            1          2 2015-07-28   5011        560     1      1
# 4            1          1 2015-07-27   6102        612     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017204   1115          6 2013-01-05   4771        339     1      0
# 1017205   1115          5 2013-01-04   4540        326     1      0
# 1017206   1115          4 2013-01-03   4297        300     1      0
# 1017207   1115          3 2013-01-02   3697        305     1      0
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# ...

# %%
# merging test and store
df_test = pd.merge(test, store, on='Store')
df_test
# Out:
#           Id  Store  DayOfWeek       Date  Open  Promo StateHoliday  \
# 0          1      1          4 2015-09-17   1.0      1            0
# 1        857      1          3 2015-09-16   1.0      1            0
# 2       1713      1          2 2015-09-15   1.0      1            0
# 3       2569      1          1 2015-09-14   1.0      1            0
# 4       3425      1          7 2015-09-13   0.0      0            0
# ...      ...    ...        ...        ...   ...    ...          ...
# 41083  37664   1115          3 2015-08-05   1.0      1            0
# 41084  38520   1115          2 2015-08-04   1.0      1            0
# 41085  39376   1115          1 2015-08-03   1.0      1            0
# 41086  40232   1115          7 2015-08-02   0.0      0            0
# 41087  41088   1115          6 2015-08-01   1.0      0            0
#
#        SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                  0         c          a               1270.0
# ...

# %% [markdown]
# ## PREPROCESSING

# %%
# checking column meta data in train set
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1017209 entries, 0 to 1017208
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Store                      1017209 non-null  int64
#  1   DayOfWeek                  1017209 non-null  int64
#  2   Date                       1017209 non-null  datetime64[ns]
#  3   Sales                      1017209 non-null  int64
#  4   Customers                  1017209 non-null  int64
#  5   Open                       1017209 non-null  int64
#  6   Promo                      1017209 non-null  int64
#  7   StateHoliday               1017209 non-null  object
#  8   SchoolHoliday              1017209 non-null  int64
#  9   StoreType                  1017209 non-null  object
#  10  Assortment                 1017209 non-null  object
#  11  CompetitionDistance        1014567 non-null  float64
# ...

# %%
# checking column meta data in test set
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41088 entries, 0 to 41087
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Id                         41088 non-null  int64
#  1   Store                      41088 non-null  int64
#  2   DayOfWeek                  41088 non-null  int64
#  3   Date                       41088 non-null  datetime64[ns]
#  4   Open                       41077 non-null  float64
#  5   Promo                      41088 non-null  int64
#  6   StateHoliday               41088 non-null  object
#  7   SchoolHoliday              41088 non-null  int64
#  8   StoreType                  41088 non-null  object
#  9   Assortment                 41088 non-null  object
#  10  CompetitionDistance        40992 non-null  float64
#  11  CompetitionOpenSinceMonth  25872 non-null  float64
#  12  CompetitionOpenSinceYear   25872 non-null  float64
# ...

# %%
df_train
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            1          4 2015-07-30   5020        546     1      1
# 2            1          3 2015-07-29   4782        523     1      1
# 3            1          2 2015-07-28   5011        560     1      1
# 4            1          1 2015-07-27   6102        612     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017204   1115          6 2013-01-05   4771        339     1      0
# 1017205   1115          5 2013-01-04   4540        326     1      0
# 1017206   1115          4 2013-01-03   4297        300     1      0
# 1017207   1115          3 2013-01-02   3697        305     1      0
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# ...

# %%
# function to fill missing column values using median
def median_fill(df, col):
    df[col] = df[col].fillna(df[col].median())

    return df[col]

# function to fill missing values using mode
def mode_fill(df, col):
    df[col] = df[col].fillna(df[col].mode()[0])

    return df[col]

# function to fill missing values based on column types
def fill_cols(df):
    for i in df.columns:
        if df.dtypes[i] == 'float64':
            df[i] = median_fill(df, i)
        elif df.dtypes[i] == 'O':
            df[i] = mode_fill(df, i)
        else: continue
    
    return df

# %%
# filling missing values
df_train = fill_cols(df_train)

# %% [markdown]
# # TASK 1

# %% [markdown]
# ## SEASONALITY IN TRAIN AND TEST SET

# %%
# For train set
# Prepare data
df_train['year'] = [d.year for d in df_train.Date]
df_train['month'] = [d.strftime('%b') for d in df_train.Date]
df_train['weekday'] = df_train['Date'].dt.day_name()
years = df_train['year'].unique()

# Prep Colors
np.random.seed(100)
mycolors = np.random.choice(list(mpl.colors.XKCD_COLORS.keys()), len(years), replace=False)

# Draw Plot
fig, axes = plt.subplots(1, 2, figsize=(20,7), dpi= 80)
sns.boxplot(x='year', y='Sales', data=df_train, ax=axes[0])
sns.boxplot(x='month', y='Sales', data=df_train)

# Set Title
axes[0].set_title('Year-wise Box Plot\n(The Trend)', fontsize=18); 
axes[1].set_title('Month-wise Box Plot\n(The Seasonality)', fontsize=18)
plt.show()

# %%
df_train
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            1          4 2015-07-30   5020        546     1      1
# 2            1          3 2015-07-29   4782        523     1      1
# 3            1          2 2015-07-28   5011        560     1      1
# 4            1          1 2015-07-27   6102        612     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017204   1115          6 2013-01-05   4771        339     1      0
# 1017205   1115          5 2013-01-04   4540        326     1      0
# 1017206   1115          4 2013-01-03   4297        300     1      0
# 1017207   1115          3 2013-01-02   3697        305     1      0
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType  ... CompetitionDistance  \
# 0                  0              1         c  ...              1270.0
# ...

# %% [markdown]
# ## CHECKING AND COMPARING SALES BEFORE, DURING AND AFTER HOLIDAYS

# %%
# checking values in state holidays column
df_train.StateHoliday.value_counts()
# Out:
# 0    855087
# 0    131072
# a     20260
# b      6690
# c      4100
# Name: StateHoliday, dtype: int64

# %%
# creating dataframe with enteries during holidays
df_dh = df_train.loc[(df_train['StateHoliday'].str.contains('a|b|c', flags=re.I, regex=True, na=False))]
df_bh
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 57           1          4 2015-06-04      0          0     0      1
# 67           1          1 2015-05-25      0          0     0      0
# 78           1          4 2015-05-14      0          0     0      0
# 91           1          5 2015-05-01      0          0     0      1
# 116          1          1 2015-04-06      0          0     0      0
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017080   1115          4 2013-05-09      0          0     0      0
# 1017088   1115          3 2013-05-01      0          0     0      1
# 1017118   1115          1 2013-04-01      0          0     0      0
# 1017121   1115          5 2013-03-29      0          0     0      1
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# ...

# %%
# creating dataframe with enteries before and after holidays
df_bah = df_train.loc[~(df_train['StateHoliday'].str.contains('a|b|c', flags=re.I, regex=True, na=False))]
df_bah
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            1          4 2015-07-30   5020        546     1      1
# 2            1          3 2015-07-29   4782        523     1      1
# 3            1          2 2015-07-28   5011        560     1      1
# 4            1          1 2015-07-27   6102        612     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017203   1115          7 2013-01-06      0          0     0      0
# 1017204   1115          6 2013-01-05   4771        339     1      0
# 1017205   1115          5 2013-01-04   4540        326     1      0
# 1017206   1115          4 2013-01-03   4297        300     1      0
# 1017207   1115          3 2013-01-02   3697        305     1      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# ...

# %%
# Draw Plot
fig, axes = plt.subplots(1, 2, figsize=(20,7), dpi= 80)
sns.barplot(x='month', y='Sales', data=df_dh, ax=axes[0])
sns.barplot(x='month', y='Sales', data=df_bah)

# Set Title
axes[0].set_title('Sales Behaviour During Holidays', fontsize=18); 
axes[1].set_title('Sales Behaviour Before and After Holidays', fontsize=18)
plt.show()

# %% [markdown]
# From the above plots, there are higher saales before and after holidays than during holidays

# %% [markdown]
# ## SEASONAL PURCHASE BEHAVIOURS

# %% [markdown]
# ### PUBLIC HOLIDAYS

# %%
# creating dataframe with enteries for public holidays
df_a = df_train.loc[(df_train['StateHoliday'].str.contains('a', flags=re.I, regex=True, na=False))]
df_a
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 57           1          4 2015-06-04      0          0     0      1
# 67           1          1 2015-05-25      0          0     0      0
# 78           1          4 2015-05-14      0          0     0      0
# 91           1          5 2015-05-01      0          0     0      1
# 211          1          4 2015-01-01      0          0     0      0
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017059   1115          4 2013-05-30      0          0     0      1
# 1017069   1115          1 2013-05-20      0          0     0      0
# 1017080   1115          4 2013-05-09      0          0     0      0
# 1017088   1115          3 2013-05-01      0          0     0      1
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType  ... CompetitionDistance  \
# 57                 a              0         c  ...              1270.0
# ...

# %%
# Draw Plot
plt.figure(figsize=(10,7), dpi= 80)
sns.barplot(x='weekday', y='Sales', data=df_a)

plt.title('Seasonal Plot of Sales On Public Holidays', fontsize=18)
plt.xlabel('Weekday',fontsize=15)
plt.ylabel('Sales',fontsize=15)
plt.show()

# %% [markdown]
# During public holidays, most sales are made on Thursdays, then  on Mondays, Fridays and Saturdays. The least sales are made on Sundays, then on Tuesdays, then Wednesdays.

# %% [markdown]
# ### EASTER HOLIDAYS

# %%
# creating dataframe with enteries for easter holidays
df_b = df_train.loc[(df_train['StateHoliday'].str.contains('b', flags=re.I, regex=True, na=False))]
df_b
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 116          1          1 2015-04-06      0          0     0      0
# 119          1          5 2015-04-03      0          0     0      1
# 466          1          1 2014-04-21      0          0     0      0
# 469          1          5 2014-04-18      0          0     0      1
# 851          1          1 2013-04-01      0          0     0      0
# ...        ...        ...        ...    ...        ...   ...    ...
# 1016386   1115          5 2015-04-03      0          0     0      1
# 1016733   1115          1 2014-04-21      0          0     0      0
# 1016736   1115          5 2014-04-18      0          0     0      1
# 1017118   1115          1 2013-04-01      0          0     0      0
# 1017121   1115          5 2013-03-29      0          0     0      1
#
#         StateHoliday  SchoolHoliday StoreType  ... CompetitionDistance  \
# 116                b              1         c  ...              1270.0
# ...

# %%
# Draw Plot
plt.figure(figsize=(10,7), dpi= 80)
sns.barplot(x='weekday', y='Sales', data=df_b)

plt.title('Seasonal Plot of Sales On Easter Holidays', fontsize=18)
plt.xlabel('Weekday',fontsize=15)
plt.ylabel('Sales',fontsize=15)
plt.show()

# %% [markdown]
# During Easter holidays, the most sales are made on Mondays then on Fridays. The difference in sales is not very significant.

# %% [markdown]
# ### CHRISTMAS HOLIDAYS

# %%
# creating dataframe with enteries for christmas holidays
df_c = df_train.loc[(df_train['StateHoliday'].str.contains('c', flags=re.I, regex=True, na=False))]
df_c
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 217          1          5 2014-12-26      0          0     0      0
# 218          1          4 2014-12-25      0          0     0      0
# 582          1          4 2013-12-26      0          0     0      0
# 583          1          3 2013-12-25      0          0     0      0
# 1159         2          5 2014-12-26      0          0     0      0
# ...        ...        ...        ...    ...        ...   ...    ...
# 1015908   1114          3 2013-12-25      0          0     0      0
# 1016484   1115          5 2014-12-26      0          0     0      0
# 1016485   1115          4 2014-12-25      0          0     0      0
# 1016849   1115          4 2013-12-26      0          0     0      0
# 1016850   1115          3 2013-12-25      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType  ... CompetitionDistance  \
# 217                c              1         c  ...              1270.0
# ...

# %%
# Draw Plot
plt.figure(figsize=(10,7), dpi= 80)
sns.barplot(x='weekday', y='Sales', data=df_c)

plt.title('Seasonal Plot of Sales On Christmas Holidays', fontsize=18)
plt.xlabel('Weekday',fontsize=15)
plt.ylabel('Sales',fontsize=15)
plt.show()

# %% [markdown]
# During Cristmas holidays, most sales are made on Fridays then Thursdays then Wednesdays. The amount of sales made on Mondays is twice the amount made on Wednesdays

# %% [markdown]
# ## CUSTOMER AND SALES CORRELATION

# %%
# Draw Plot
plt.figure(figsize=(10,7), dpi= 80)
sns.scatterplot(x='Customers', y='Sales', data=df_c)

plt.title('Correlation Between No. of Customers And Sales', fontsize=18)
plt.xlabel('No. Of Customers',fontsize=15)
plt.ylabel('Sales',fontsize=15)
plt.show()

# %% [markdown]
# The plot above shows that the number of customers and sales are positively linearly correlated. The higher the number of customers the higher the sales.

# %% [markdown]
# ## EFFECT OF PROMOS ON SALES

# %%
# Draw Plot
plt.figure(figsize=(10,7), dpi= 80)
sns.barplot(x='Promo2', y='Sales', data=df_train)

plt.title('Effect Of Promos On Sales', fontsize=18)
plt.xlabel('Promo',fontsize=15)
plt.ylabel('Sales',fontsize=15)
plt.show()

# %% [markdown]
# The above chart shows that more sales are made during promos.

# %% [markdown]
# ## STORES PROMOS SHOULD BE DEPLOYED IN MOST

# %%
# creating dataframe with enteries for when there is a promo
df_promo = df_train.loc[(df_train['Promo2'] == 1)]
df_promo
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 942          2          5 2015-07-31   6064        625     1      1
# 943          2          4 2015-07-30   5567        601     1      1
# 944          2          3 2015-07-29   6402        727     1      1
# 945          2          2 2015-07-28   5671        646     1      1
# 946          2          1 2015-07-27   6627        638     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017204   1115          6 2013-01-05   4771        339     1      0
# 1017205   1115          5 2013-01-04   4540        326     1      0
# 1017206   1115          4 2013-01-03   4297        300     1      0
# 1017207   1115          3 2013-01-02   3697        305     1      0
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# ...

# %%
top_stores = df_promo.groupby('Store').agg({'Sales': 'sum'}).sort_values(by='Sales', ascending=False)[:10]
top_stores
# Out:
#           Sales
# Store
# 756    12911782
# 335    12541731
# 380    11261676
# 544    10993709
# 769    10198000
# 261     9828244
# 1014    9509102
# 449     8789176
# 479     8782548
# 502     8377408

# %%
# Plot of top 10 stores with the best sales from promos
plt.figure(figsize=(10,7), dpi= 80)
sns.barplot(top_stores.index, top_stores.Sales)

plt.title('Most Effective Promo Sales Stores', fontsize=18)
plt.xlabel('Stores',fontsize=15)
plt.ylabel('Sales',fontsize=15)
plt.show()

# %% [markdown]
# The chart above shows the top 10 stores where promos gives the largest boost in sales.

# %% [markdown]
# ## EFFECT OF ASSORTMENT TYPE ON SALES

# %%
# Draw Plot
plt.figure(figsize=(10,7), dpi= 80)
sns.barplot(x='Assortment', y='Sales', data=df_train)

plt.title('Effect Of Assortment Type On Sales', fontsize=18)
plt.xlabel('Assortment Type',fontsize=15)
plt.ylabel('Sales',fontsize=15)
plt.show()

# %% [markdown]
# From the chart above, the stores with assortment type b (extra level) have the highest sales, followed by stores with assortment type c (extended level). Assortment Type a (basic level) stores have the least sales.

# %% [markdown]
# ## EFFECT OF COMPETITOR DISTANCE ON SALES

# %%
# Draw Plot
plt.figure(figsize=(10,7), dpi= 80)
sns.scatterplot(x='CompetitionDistance', y='Sales', data=df_train.loc[(df_train['Open'] == 1)])

plt.title('Correlation Between Competitor Distance And Sales', fontsize=18)
plt.xlabel('Competitor Distance',fontsize=15)
plt.ylabel('Sales',fontsize=15)
plt.show()

# %% [markdown]
# The plot above shows that the distance of a competitor store has no correlation with the sales a store makes, because, we can see that some of the highest sales were made with competitors at the closest distance.

# %% [markdown]
# # TASK 2

# %% [markdown]
# ## Task 2.1 - PREPROCESSING

# %%
# extracting weekdays
df_train['weekday'] = df_train['Date'].dt.day_name()

# %%
# extracting weekends
lst = []
for i in df_train['weekday']:
    if (i == 'Saturday') | (i == 'Saturday'):
        lst.append(1)
    else:
        lst.append(0)
df_train['weekends'] = lst

df_train.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      1          4 2015-07-30   5020        546     1      1            0
# 2      1          3 2015-07-29   4782        523     1      1            0
# 3      1          2 2015-07-28   5011        560     1      1            0
# 4      1          1 2015-07-27   6102        612     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         c          a               1270.0
# 2              1         c          a               1270.0
# 3              1         c          a               1270.0
# 4              1         c          a               1270.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# ...

# %%
# extracting number of days to holidays
holidays = df_train.loc[(df_train['StateHoliday'].str.contains('a|b|c', flags=re.I, regex=True, na=False))].index

everyday = df_train.index

check = []
holder = 0
for i in holidays:
    temp_df = df_train.iloc[holder:i, :]
    for j in temp_df.index:
        val = i -j
        check.append(val)
    holder = i
check.append(120)
df_train['days2holiday'] = check
df_train.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      1          4 2015-07-30   5020        546     1      1            0
# 2      1          3 2015-07-29   4782        523     1      1            0
# 3      1          2 2015-07-28   5011        560     1      1            0
# 4      1          1 2015-07-27   6102        612     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         c          a               1270.0
# 2              1         c          a               1270.0
# 3              1         c          a               1270.0
# 4              1         c          a               1270.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# ...

# %%
# extracting number of days after holidays

check2 = []

for i in everyday:

    for j in holidays:
        val = i - j
        if val < 0:
            check2.append(0)
            br
        elif val == 0:
            check2.append(val)
            break
        else:
            check2.append(val)
            break
df_train['day2holiday'] = check

df_train.head()

# %%
a = 2
for i in range(10):
    a = a-1
    if a <= 0: break
    print(a)
# Out:
# 1

# %%
120 in check
# Out:
# True

# %%
pd.date_range(start='1/1/1980', end='11/1/1991', freq='M')
